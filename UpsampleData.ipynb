# %% [markdown]
# # Evaluating Upsampled data

# %% [markdown]
# ### Comparing Upsampled Memorization score vs. KDE Simmilarity Score

# %%
import FunctionsAndData as fd
upsample = fd.memscore_df_upsample
pickle = fd.pickle
kde = fd.kde_scores(pickle)
fd.plotter(upsample, kde, 'KDE')
# Out:
# Error reading data/strive.libset_len30-600_nr80_train-valid.l4c64.scheduler_validobj_rand50.006/strive_2022.libset_len30-600_nr80_train-valid_VL.eval/eval_loss_meta.csv
# Error reading data/strive.libset_len30-600_nr80_train-valid.l4c64.scheduler_validobj_rand50.066/strive_2022.libset_len30-600_nr80_train-valid_TR.eval/eval_loss_meta.csv
# templFile     34661     31262     37294     34263     27176     25356  \
# queryFile
# 34661      1.000000  0.522727  0.296296  0.590909  0.201550  0.272727
# 31262      0.522727  1.000000  0.249275  0.564706  0.149020  0.277457
# 37294      0.296296  0.249275  1.000000  0.272464  0.280292  0.241843
# 34263      0.590909  0.564706  0.272464  1.000000  0.168627  0.260116
# 27176      0.201550  0.149020  0.286131  0.168627  1.000000  0.306122
# ...             ...       ...       ...       ...       ...       ...
# 26367      0.187867  0.205941  0.291176  0.154455  0.321893  0.346549
# ...

# %% [markdown]
# ### Comparing Upsampled Memorization score vs. Exponential Decay Simmilarity Score

# %%
exp_decay = fd.exponential_sim_scores(pickle)
fd.plotter(upsample, exp_decay, 'Exponential Decay')
# Out:
# The exponential decay equation is: y = 0.19 * e^(-0.71 * x) + 0.01

# %% [markdown]
# ### Comparing Upsampled Memorization score vs. Quanta Simmilarity Score

# %%
quanta = fd.quanta_simscore(pickle)
fd.plotter(upsample, quanta, 'Quanta')
# Out:
# /Users/ilanastern/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ilanastern/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/ilanastern/Documents/GitHub/aiConfidential/FunctionsAndData.py:106: RuntimeWarning: invalid value encountered in multiply
#   return a * np.exp(-b * x) + c
# The exponential decay equation is: y = -559153.25 * e^(-40354.25 * x) + 0.05
